# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerimson/August_Coding/blob/main/230808_%EB%A9%80%ED%8B%B0%EC%BA%A0%EC%B7%A8%EC%97%85%EC%BA%A0%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##[책 보기 - 파이썬 머신러닝 판다스 데이터 분석]
#
# 내가 알고 있는 데이터 타입으로 바꾸기

# %%
import pandas as pd

# %%
list = ['2020-10-10',3.14,'ABC','True',100]
sr = pd.Series(list)
print(sr)
# Out:
# 0    2020-10-10
# 1          3.14
# 2           ABC
# 3          True
# 4           100
# dtype: object

# %%
idx = sr.index
val = sr.values
print(idx)
print('\n')
print(val)
# Out:
# RangeIndex(start=0, stop=5, step=1)
#
#
# ['2020-10-10' 3.14 'ABC' 'True' 100]

# %%
# 15, 남, 덕영중
# 17, 여, 수리중

# 2 x 3 matrix (row가 2, column이 3) # 2차원 배열

# (1, 2, 3)  # 1 x 3 matrix
# 1
# 2
# 3
# 3 x 1 matrix
#==> 이것까지도 가로와 세로가 모두 있기에 2차원 배열
# [[ ]] 대괄호 두개면 2차원이다
# [[15,'남','덕영중]] : (1,3) 이라서 2차원배열

#그냥 직선 하나(가로 하나 or 세로 하나라고 안함)  -> 1차원 배열
# ex) (3,)

# %%
import pandas as pd

# %%
df = pd.DataFrame([[15,'남','덕영중'],[17,'여','수리중']])

# %%
df
# Out:
#     0  1    2
# 0  15  남  덕영중
# 1  17  여  수리중

# %%
df.index = ['학생1', '학생2']
df.columns = ['연령','남녀','소속']

# %%
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
df.index
# Out:
# Index(['학생1', '학생2'], dtype='object')

# %%
df.columns
# Out:
# Index(['연령', '남녀', '소속'], dtype='object')

# %%
df2 = df

# %%
df3 = df[:]

# %%
df2
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
df3
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
df2.drop('학생1', inplace=True)
df2
# Out:
#      연령 남녀   소속
# 학생2  17  여  수리중

# %%
df = df3[:]

# %%
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
df3.drop('학생2',inplace=True)
df3
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중

# %%
df  #df는 안바뀌어있다
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
import pandas as pd

# %%
exam_data = {'이름':['서준','우현','인아'],
             '수학':[90,80,70],
             '영어':[98,89,95],
             '음악':[85,95,100],
             '체육':[100,90,90]}

df = pd.DataFrame(exam_data)
df.set_index('이름',inplace=True)

print(df)
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
a = df.loc['서준','음악']
print(a)

b = df.iloc[0,2]
print(b)
# Out:
# 85
# 85

# %%
c = df.loc['서준',['음악','체육']]
print(c)

d = df.iloc[0,[2,3]]
print(d)

e = df.loc['서준','음악':'체육']
print(e)

f = df.iloc[0,2:]
print(f)
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
g = df.loc[['서준','우현'],['음악','체육']]
print(g)

h = df.iloc[[0,1],[2,3]]
print(h)

i = df.loc['서준':'우현','음악':'체육']
print(i)

j = df.iloc[0:2,2:]
print(j)
# Out:
#     음악   체육
# 이름
# 서준  85  100
# 우현  95   90
#     음악   체육
# 이름
# 서준  85  100
# 우현  95   90
#     음악   체육
# 이름
# 서준  85  100
# 우현  95   90
#     음악   체육
# 이름
# 서준  85  100
# 우현  95   90

# %%
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df.loc['영']=0

# %%
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90
# 영    0   0    0    0

# %%
df.loc['동규']=[90,80,70,60]

# %%
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90
# 영    0   0    0    0
# 동규  90  80   70   60

# %%
import pandas as pd

exam_data = {'이름':['서준','우현','인아'],
             '수학':[90,80,70],
             '영어':[98,89,95],
             '음악':[85,95,100],
             '체육':[100,90,90]}

df = pd.DataFrame(exam_data)

df.set_index('이름',inplace=True)
print(df)
print('\n')

df.iloc[0][3] = 80
print(df)
print('\n')

df.loc['서준']['체육'] = 90   #형식 눈여겨보기
print(df)
print('\n')

df.loc['서준','체육'] = 100
print(df)
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90
#
#
#     수학  영어   음악  체육
# 이름
# 서준  90  98   85  80
# 우현  80  89   95  90
# 인아  70  95  100  90
#
#
#     수학  영어   음악  체육
# 이름
# 서준  90  98   85  90
# 우현  80  89   95  90
# 인아  70  95  100  90
#
#
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df.loc['서준',['음악','체육']] = 50
print(df)
print('\n')

df.loc['서준',['음악','체육']] = 100, 50
print(df)
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98   50  50
# 우현  80  89   95  90
# 인아  70  95  100  90
#
#
#     수학  영어   음악  체육
# 이름
# 서준  90  98  100  50
# 우현  80  89   95  90
# 인아  70  95  100  90

# %%
df.transpose()
# Out:
# 이름   서준  우현   인아
# 수학   90  80   70
# 영어   98  89   95
# 음악  100  95  100
# 체육   50  90   90

# %%
df
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98  100  50
# 우현  80  89   95  90
# 인아  70  95  100  90

# %%
import pandas as pd

exam_data = {'이름':['서준','우현','인아'],
             '수학':[90,80,70],
             '영어':[98,89,95],
             '음악':[85,95,100],
             '체육':[100,90,90]}

df = pd.DataFrame(exam_data)
print(df)
print('\n')

ndf = df.set_index(['이름'])
print(ndf)
print('\n')

ndf2 = ndf.set_index('음악')
print(ndf2)
print('\n')

ndf3 = ndf.set_index(['수학','음악'])
print(ndf3)
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
#
#
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90
#
#
#      수학  영어   체육
# 음악
# 85   90  98  100
# 95   80  89   90
# 100  70  95   90
#
#
#         영어   체육
# 수학 음악
# 90 85   98  100
# 80 95   89   90
# 70 100  95   90

# %%
ndf
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
ndf2
# Out:
#      수학  영어   체육
# 음악
# 85   90  98  100
# 95   80  89   90
# 100  70  95   90

# %%
ndf3  #멀티인덱스
# Out:
#         영어   체육
# 수학 음악
# 90 85   98  100
# 80 95   89   90
# 70 100  95   90

# %%
#딕셔너리를 지정
dict_data = {'c0':[1,2,3],'c1':[4,5,6],'c2':[7,8,9],'c3':[10,11,12],'c4':[13,14,15]}

df = pd.DataFrame(dict_data,index = ['r0','r1','r2'])
print(df)
print('\n')

#인덱스를 [r0,r1,r2,r2,r4]로 재지정
new_index = ['r0','r1','r2','r3','r4']
ndf = df.reindex(new_index)
print(ndf)
print('\n')

#reindex로 발생한 NaN값을숫자 0으로 채우기
new_index = ['r0','r1','r2','r3','r4']
ndf2 = df.reindex(new_index,fill_value = 0)
print(ndf2)
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
#
#
#      c0   c1   c2    c3    c4
# r0  1.0  4.0  7.0  10.0  13.0
# r1  2.0  5.0  8.0  11.0  14.0
# r2  3.0  6.0  9.0  12.0  15.0
# r3  NaN  NaN  NaN   NaN   NaN
# r4  NaN  NaN  NaN   NaN   NaN
#
#
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
# r3   0   0   0   0   0
# r4   0   0   0   0   0

# %%
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
df.reset_index()  #원래 사용했던 인덱스는 칼럼으로 올라간다
# Out:
#   index  c0  c1  c2  c3  c4
# 0    r0   1   4   7  10  13
# 1    r1   2   5   8  11  14
# 2    r2   3   6   9  12  15

# %%
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
df.sort_index(ascending=False)
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %%
df.sort_index(ascending=True)
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
df.sort_values(by='c1',ascending=False)
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %%
import numpy as np

# %%
student1 = pd.Series({'국아':np.nan, '영어':80,'수학':90})
student2 = pd.Series({'수학':80,'국어':90,'영어':80})

# %%
student1
# Out:
# 국아     NaN
# 영어    80.0
# 수학    90.0
# dtype: float64

# %%
import pandas as pd
import seaborn as sns  #그래픽 라이브러리

# %%
titanic  = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df = titanic.loc[:,['age','fare']]

# %% [markdown]
# 0-냉장고, 세탁기-1, 에어컨 -2 라고 정하자

# %%
df = titanic.loc[:,['age','fare']]
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df + 10
# Out:
#       age     fare
# 0    32.0  17.2500
# 1    48.0  81.2833
# 2    36.0  17.9250
# 3    45.0  63.1000
# 4    45.0  18.0500
# ..    ...      ...
# 886  37.0  23.0000
# 887  29.0  40.0000
# 888   NaN  33.4500
# 889  36.0  40.0000
# 890  42.0  17.7500
#
# [891 rows x 2 columns]

# %%
add_df = df +10

# %%
add_df
# Out:
#       age     fare
# 0    32.0  17.2500
# 1    48.0  81.2833
# 2    36.0  17.9250
# 3    45.0  63.1000
# 4    45.0  18.0500
# ..    ...      ...
# 886  37.0  23.0000
# 887  29.0  40.0000
# 888   NaN  33.4500
# 889  36.0  40.0000
# 890  42.0  17.7500
#
# [891 rows x 2 columns]

# %%
add_df- df
# Out:
#       age  fare
# 0    10.0  10.0
# 1    10.0  10.0
# 2    10.0  10.0
# 3    10.0  10.0
# 4    10.0  10.0
# ..    ...   ...
# 886  10.0  10.0
# 887  10.0  10.0
# 888   NaN  10.0
# 889  10.0  10.0
# 890  10.0  10.0
#
# [891 rows x 2 columns]

# %%
df.head(13)  #처음부터 13개 보여준다
# Out:
#      age     fare
# 0   22.0   7.2500
# 1   38.0  71.2833
# 2   26.0   7.9250
# 3   35.0  53.1000
# 4   35.0   8.0500
# 5    NaN   8.4583
# 6   54.0  51.8625
# 7    2.0  21.0750
# 8   27.0  11.1333
# 9   14.0  30.0708
# 10   4.0  16.7000
# 11  58.0  26.5500
# 12  20.0   8.0500

# %%
df.tail(12)  #끝에서부터 12개 보여준다
# Out:
#       age     fare
# 879  56.0  83.1583
# 880  25.0  26.0000
# 881  33.0   7.8958
# 882  22.0  10.5167
# 883  28.0  10.5000
# 884  25.0   7.0500
# 885  39.0  29.1250
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500

# %% [markdown]
# 1. 가상환경 구축
# 2. streamlit 라이브러리 (자체 조사, dataframe 표출 방법)

# %% [markdown]
# ##1. 가상환경 구축
#  - conda env list : 기존 가상환경목록 확인
#  - conda create -n prjsmi python=3.9 ipytho numpy pandas matplotlib scipy
#
#  (y 입력, 설치완료 확인 conda activate prjsmi 문구 확인)
#
# - conda activate prjsmi : 가상환경 진입
#    (프롬포트에 prjsmi 가 나오는지 확인)
# - python과 라이브러리 설치 유무 확인
# - streamlit 설치 : pip install steamlit
#
#     (에러 - winerr 225 : 백신 끄고 streamlit 설치로 해결)
#
# - python 실행후 import streamlit으로 스트림릿 설치 유무 확인
# - conda deactivate : 가상환경 종
